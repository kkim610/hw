# %% [markdown]
# # HW 2

# %% [markdown]
# 제출기한: 2022년 4월 22일
# 제출방법: HiClass hw2 과제함

# %% [markdown]
# 배점: 5점

# %% [markdown]
# hw2.csv 에 4개의 입력변수(R,A,M,S)와 한 개의 출력변수(Profit)로 구성된 샘플이 50개 있다.
#
# Pytorch를 이용하여 다음 조건하에서 Multivariate Linear Regression을 실행하시오.
# Loss: MSE
# Learning rate: 0.1
# Optimizer: Adam
# Number of epoch: 100

# %% [markdown]
# 최종 LOSS를 인쇄하시오.
# 힌트: from sklearn.preprocessing import OneHotEncoder 를 사용하여 S(State를 나타냄)열을 3개의 열(모두 숫자로 변환됨)로 변환한 후 Multivariate Linear Regression을 실행
